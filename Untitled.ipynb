# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv("NIFTY50.csv")

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
plt.plot(df["Date"],df["Close"])

# %%
# !pip3 install scipy
# Out:
# Requirement already satisfied: scipy in /Users/akshatnahata/opt/anaconda3/lib/python3.9/site-packages (1.9.1)
# Requirement already satisfied: numpy<1.25.0,>=1.18.5 in /Users/akshatnahata/opt/anaconda3/lib/python3.9/site-packages (from scipy) (1.21.5)

# %%
from scipy.signal import argrelextrema

# Generate a noisy AR(1) sample

# np.random.seed(0)
# rs = np.random.randn(200)
# xs = [0]
# for r in rs:
#     xs.append(xs[-1] * 0.9 + r)

df = pd.DataFrame(df,columns=['Close'])

# n = 5  # number of points to be checked before and after

# Find local peaks
# print(df)
df['min'] = df.iloc[argrelextrema(df.Close.values, np.less_equal,
                    order=n)[0]]['Close']
df['max'] = df.iloc[argrelextrema(df.Close.values, np.greater_equal,
                    order=n)[0]]['Close']

# Plot results

plt.scatter(df.index, df['min'], c='r')
plt.scatter(df.index, df['max'], c='g')
plt.plot(df.index, df['Close'])

plt.savefig('books_read.png')
plt.show()
